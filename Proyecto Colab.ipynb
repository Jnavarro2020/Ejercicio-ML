# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
import seaborn as sns
import matplotlib.pyplot as plt

# cargamos el archivo scv
df = pd.read_csv("https://raw.githubusercontent.com/Jnavarro2020/Ejercicio-ML/refs/heads/main/Archico%20csv.csv")

# %%
df.head(10)
# Out:
#         FECHA  EDAD SEXO   GLU   PSA
# 0  02/01/2020    41    F  0,83   NaN
# 1  02/01/2020    16    F  0,74   NaN
# 2  02/01/2020    75    M  2,55   NaN
# 3  02/01/2020    85    F  0,92   NaN
# 4  02/01/2020    33    M  1,05   NaN
# 5  02/01/2020    53    M  1,05   NaN
# 6  02/01/2020    70    M   NaN  7,06
# 7  02/01/2020    15    F  0,91   NaN
# 8  02/01/2020    20    F  0,89   NaN
# 9  02/01/2020    47    F  1,09   NaN

# %%
df.describe()
# Out:
#                EDAD
# count  33101.000000
# mean      49.763904
# std       21.045324
# min        0.000000
# 25%       31.000000
# 50%       52.000000
# 75%       67.000000
# max      104.000000

# %%
# Boxplots
#sns.boxplot()
plt.figure(figsize=(12, 6))
#sns.boxplot( data=df)
sns.boxplot(x='GLU', y='EDAD', data=df)
plt.title('Grafico de las Variables')
plt.show()
